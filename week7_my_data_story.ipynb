# %% [markdown]
# **MY DATA STORY**

# %% [markdown]
# **About my file :**
# My file contains two choices :
# 1.List of my Goals For this semester
# 2.List of my favourite movies
# ( my file and code contains necessary technical requirments like total no. of line count and total no. of word counts ,necessary AI collaboration documentation ,and Personal Reflection as mentioned .)

# %%
##1.List of my goals for this semester 

#First , defining the file 
filename = "my_data.txt"
with open(filename, "r") as file:
    lines = file.readlines()

print("*** MY DATA STORY ***")
for line in lines:
    print(line.strip())
    
#Here displaying number of lines and word counts 
print("\nTotal number of lines:", len(lines))
word_count = sum(len(line.split()) for line in lines)
print("Total number of words:", word_count)
# Out:
# *** MY DATA STORY ***
#
# List of my goals for this semester :
#
# I want to improve my programming skills
# I will attend all my lectures regularly
# I plan to complete assignments on time
# I want to get better at Python coding
# I will practice coding at least 1 hour daily
# I aim to improve my communication skills
# I want to manage my time effectively
# I will focus on achieving good grades
# I plan to learn new technologies
# I want to balance study and part-time work
#
#
# Total number of lines: 14
# Total number of words: 81

# %% [markdown]
# # AI Collaboration Log
#
# **My AI Prompt:**
# "I am a beginner learning Python. I have a text file containg list of my goals for this semester and I want a simple program to read the file and display it with in begineer friendly form ,which also helps me calculate total no. of lines and word count in the text file. Can you help?"
#
# **What the AI Helped Me With:**
# The AI helped me write simple Python code to open and read the file, print the content, and count the number of lines and words in the text file and also suggested me to save my text file and program in the same folder .
#
# **What I Learned:**
# I learned how to open and read a file in Python using `open()`,how to process text data using loops and functions like `len()` and `split()`.
# I also learned how to count words by splitting the text.
# I understood that for file handling to work, my code file and text file need to be saved in the same folder so Python can find the file.
# The code is similar to other basic programs, but file handling is different because it works with external files instead of just variables.

# %% [markdown]
# # My Reflection
#
# **What surprised me about working with files:**
# I was surprised that Python can easily read and analyze files aswell. I didn’t expect it to be this simple, and I can see how useful it is for working with things like security logs.Also i reaized that while using file handeling it is important to save our text/.txt files and our program in the same folder even in Python , just like any other programming languages like C ,C++ etc .
#
# **How this connects to business:**
# In cybersecurity and business in general, files are used to store important information like logs, user data, and security reports. Being able to read and analyze these files can help in making better decisions and finding problems.
# For Example: In a college, Python and file handeling can be used to read student records from files and analyze things like grades or attendance to help track student performance.
#
# **Next thing I want to learn:**
# I want to learn how to analyze log files in more detail and detect possible security issues using Python.

# %%
#Choice no. 2 (List of my Fav Movies)

filename = "my_data1.txt"
with open(filename, "r") as file:
    lines = file.readlines()

print("*** MY DATA STORY ***")
for line in lines:
    print(line.strip())

print("\nTotal number of lines:", len(lines))
word_count = sum(len(line.split()) for line in lines)
print("Total number of words:", word_count)
# Out:
# *** MY DATA STORY ***
#
# List of my favorite movies:
#
# The Notebook
# Conjuring
# Koi Mil Gaya
# Kabhi Khusi Kabhi Gam
# Hereditary
# The Mummy Returns
# Cruel Intentions
# The Misssing Booth
# Culpa Mia
# Culpa Tuya
# Dora and the lost City of Gold
# Secret Santa
# The Return Of Rebel
# Bazzigar
#
# Total number of lines: 17
# Total number of words: 42

# %% [markdown]
# # Learning and Remarks for choice 2
# For this choice of my favourite movies, I applied the knowledge I learned from the first task above and I created a new text file and made a list of my favourite movies in it. Then I wrote a Python program to read the file, display each line, and calculate basic statistics like the total number of lines and words.
#
# This helped me understand how file handling works in Python, especially how we can work with external files instead of only using data inside the program. I also practiced doing it on my own, which improved my confidence in using Python for simple data processing tasks.
